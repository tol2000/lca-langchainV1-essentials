// %% [markdown]
// ## Fast Agent

// %% [markdown]
// <img src="./assets/LC_L1_Top.png" align="left" width="500" />

// %% [markdown]
// First, let's set up our SQLite database connection using the Chinook sample database.

// %%
import * as setup from "./setup.ts";
import { SqlDatabase } from "@langchain/classic/sql_db";
import { DataSource } from "typeorm";

const datasource = new DataSource({
    type: "sqlite",
    database: "./Chinook.db", // Replace with the link to your database
});
export const db = await SqlDatabase.fromDataSourceParams({
    appDataSource: datasource,
});

// %% [markdown]
// Create a tool that executes SQL queries against our database.
//
// <b>⚠️ Security Note:</b> This demo does not include a filter on LLM-generated commands. In production, you would want to limit the scope of LLM-generated commands. ⚠️

// %%
import { tool } from "langchain";
import { z } from "zod";

export const executeSQL = tool(({ query }, runtime) => {
    return runtime.context.db.run(query)
}, {
    name: "execute_sql",
    description: "Execute a SQLite command and return results.",
    schema: z.object({ query: z.string() })
})

// %% [markdown]
// Define a system prompt with clear rules for the agent to follow when querying the database.

// %%
export const systemPrompt = `You are a careful SQLite analyst.

Rules:
- Think step-by-step.
- When you need data, call the tool \`execute_sql\` with ONE SELECT query.
- Read-only only; no INSERT/UPDATE/DELETE/ALTER/DROP/CREATE/REPLACE/TRUNCATE.
- Limit to 5 rows of output unless the user explicitly asks otherwise.
- If the tool returns 'Error:', revise the SQL and try again.
- Prefer explicit column lists; avoid SELECT *.`

// %% [markdown]
// Now we can create our agent by combining the model, tools, and system prompt.

// %%
import * as z from "zod";
import { createAgent } from "langchain";

const contextSchema = z.object({
    db: z.instanceof(SqlDatabase),
});

const agent = createAgent({
    model: process.env.AI_MODEL || "anthropic:claude-sonnet-4-6",
    tools: [executeSQL],
    systemPrompt,
    contextSchema,
});

// %% [markdown]
// Let's visualize the agent's graph structure.

// %%
await agent.drawMermaidPng()

// %% [markdown]
// Run some queries. Notice:
// - The agent does not have the database schema and will need to discover it independently.
// - The agent may make mistakes! By returning error messages, the agent can self-correct its queries.
// - Notice you invoke the agent with `agent.stream`.
// - Notice the agent doesn't remember the schema between invocations... More on this later!

// %% [markdown]
// Time to test it! Let's ask which table has the most entries.

// %%
const stream = await agent.stream({
    messages: "Which table has the largest number of entries?"
}, {
    streamMode: "values",
    context: {
        db,
    }
})

for await (const step of stream) {
    const lastMessage = step?.messages?.at(-1)
    displayMessage(lastMessage)
}
// Out:
// ┌────────────────────────────────────────────────────────────┐
// │ 👤 HUMAN MESSAGE                                           │
// └────────────────────────────────────────────────────────────┘
// Which table has the largest number of entries?
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "text",
//     text: "Let me start by finding all the tables in the database, then count the entries in each one."
//   },
//   {
//     type: "tool_use",
//     id: "toolu_016jN1yA1aoXDuagCuS6fY7d",
//     name: "execute_sql",
//     input: {
//       query: "SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;"
//     },
//     caller: { type: "direct" }
//   }
// ]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"name":"Album"},{"name":"Artist"},{"name":"Customer"},{"name":"Employee"},{"name":"Genre"},{"name":"Invoice"},{"name":"InvoiceLine"},{"name":"MediaType"},{"name":"Playlist"},{"name":"PlaylistTrack"},{"name":"Track"}]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "text",
//     text: "Now let me count the rows in all 11 tables at once!"
//   },
//   {
//     type: "tool_use",
//     id: "toolu_017ucPkXjUHTGrVTPDY8Jade",
//     name: "execute_sql",
//     input: {
//       query: "SELECT 'Album' AS TableName, COUNT(*) AS RowCount FROM Album\n" +
//         "UNION ALL SELECT 'Artist', COUNT(*) FROM Artist\n" +
//         "UNION ALL SELECT 'Customer', COUNT(*) FROM Customer\n" +
//         "UNION ALL SELECT 'Employee', COUNT(*) FROM Employee\n" +
//         "UNION ALL SELECT 'Genre', COUNT(*) FROM Genre\n" +
//         "UNION ALL SELECT 'Invoice', COUNT(*) FROM Invoice\n" +
//         "UNION ALL SELECT 'InvoiceLine', COUNT(*) FROM InvoiceLine\n" +
//         "UNION ALL SELECT 'MediaType', COUNT(*) FROM MediaType\n" +
//         "UNION ALL SELECT 'Playlist', COUNT(*) FROM Playlist\n" +
//         "UNION ALL SELECT 'PlaylistTrack', COUNT(*) FROM PlaylistTrack\n" +
//         "UNION ALL SELECT 'Track', COUNT(*) FROM Track\n" +
//         "ORDER BY RowCount DESC;"
//     },
//     caller: { type: "direct" }
//   }
// ]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"TableName":"PlaylistTrack","RowCount":8715},{"TableName":"Track","RowCount":3503},{"TableName":"InvoiceLine","RowCount":2240},{"TableName":"Invoice","RowCount":412},{"TableName":"Album","RowCount":347},{"TableName":"Artist","RowCount":275},{"TableName":"Customer","RowCount":59},{"TableName":"Genre","RowCount":25},{"TableName":"Playlist","RowCount":18},{"TableName":"Employee","RowCount":8},{"TableName":"MediaType","RowCount":5}]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// The **PlaylistTrack** table has the largest number of entries with **8,715 rows**. Here's a full ranking of all tables for reference:
//
// | Rank | Table | Row Count |
// |------|---------------|-----------|
// | 🥇 1 | PlaylistTrack | 8,715 |
// | 2 | Track | 3,503 |
// | 3 | InvoiceLine | 2,240 |
// | 4 | Invoice | 412 |
// | 5 | Album | 347 |
// | 6 | Artist | 275 |
// | 7 | Customer | 59 |
// | 8 | Genre | 25 |
// | 9 | Playlist | 18 |
// | 10 | Employee | 8 |
// | 11 | MediaType | 5 |

// %% [markdown]
// Now let's try a more complex analytical query involving joins and aggregations.

// %%
const question = "Which genre on average has the longest tracks?"
const stream = await agent.stream({
    messages: question
}, {
    streamMode: "values",
    context: {
        db,
    }
})

for await (const step of stream) {
    const lastMessage = step?.messages?.at(-1)
    displayMessage(lastMessage)
}
// Out:
// ┌────────────────────────────────────────────────────────────┐
// │ 👤 HUMAN MESSAGE                                           │
// └────────────────────────────────────────────────────────────┘
// Which genre on average has the longest tracks?
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "text",
//     text: "Let me first explore the database schema to understand the relevant tables."
//   },
//   {
//     type: "tool_use",
//     id: "toolu_01WHRRJivge576iyuaLTTa7z",
//     name: "execute_sql",
//     input: { query: "SELECT name FROM sqlite_master WHERE type='table'" },
//     caller: { type: "direct" }
//   }
// ]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"name":"Album"},{"name":"Artist"},{"name":"Customer"},{"name":"Employee"},{"name":"Genre"},{"name":"Invoice"},{"name":"InvoiceLine"},{"name":"MediaType"},{"name":"Playlist"},{"name":"PlaylistTrack"},{"name":"Track"}]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "tool_use",
//     id: "toolu_017iwQWQY8BAiPdsPtYSwzHW",
//     name: "execute_sql",
//     input: {
//       query: "SELECT name, sql FROM sqlite_master WHERE type='table' AND name IN ('Genre', 'Track')"
//     },
//     caller: { type: "direct" }
//   }
// ]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"name":"Genre","sql":"CREATE TABLE [Genre]\n(\n    [GenreId] INTEGER  NOT NULL,\n    [Name] NVARCHAR(120),\n    CONSTRAINT [PK_Genre] PRIMARY KEY  ([GenreId])\n)"},{"name":"Track","sql":"CREATE TABLE [Track]\n(\n    [TrackId] INTEGER  NOT NULL,\n    [Name] NVARCHAR(200)  NOT NULL,\n    [AlbumId] INTEGER,\n    [MediaTypeId] INTEGER  NOT NULL,\n    [GenreId] INTEGER,\n    [Composer] NVARCHAR(220),\n    [Milliseconds] INTEGER  NOT NULL,\n    [Bytes] INTEGER,\n    [UnitPrice] NUMERIC(10,2)  NOT NULL,\n    CONSTRAINT [PK_Track] PRIMARY KEY  ([TrackId]),\n    FOREIGN KEY ([AlbumId]) REFERENCES [Album] ([AlbumId]) \n\t\tON DELETE NO ACTION ON UPDATE NO ACTION,\n    FOREIGN KEY ([GenreId]) REFERENCES [Genre] ([GenreId]) \n\t\tON DELETE NO ACTION ON UPDATE NO ACTION,\n    FOREIGN KEY ([MediaTypeId]) REFERENCES [MediaType] ([MediaTypeId]) \n\t\tON DELETE NO ACTION ON UPDATE NO ACTION\n)"}]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "tool_use",
//     id: "toolu_01VFLykGRJpJHeb4aS8cCyNd",
//     name: "execute_sql",
//     input: {
//       query: "\n" +
//         "SELECT \n" +
//         "    g.Name AS Genre,\n" +
//         "    COUNT(t.TrackId) AS TrackCount,\n" +
//         "    ROUND(AVG(t.Milliseconds) / 60000.0, 2) AS AvgDuration_Minutes\n" +
//         "FROM Genre g\n" +
//         "JOIN Track t ON g.GenreId = t.GenreId\n" +
//         "GROUP BY g.GenreId, g.Name\n" +
//         "ORDER BY AvgDuration_Minutes DESC\n" +
//         "LIMIT 5\n"
//     },
//     caller: { type: "direct" }
//   }
// ]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"Genre":"Sci Fi & Fantasy","TrackCount":26,"AvgDuration_Minutes":48.53},{"Genre":"Science Fiction","TrackCount":13,"AvgDuration_Minutes":43.76},{"Genre":"Drama","TrackCount":64,"AvgDuration_Minutes":42.92},{"Genre":"TV Shows","TrackCount":93,"AvgDuration_Minutes":35.75},{"Genre":"Comedy","TrackCount":17,"AvgDuration_Minutes":26.42}]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// The genre with the longest average track duration is **Sci Fi & Fantasy**, with an average track length of **48.53 minutes** across 26 tracks! 🎬
//
// Here are the **Top 5 genres by average track length**:
//
// | Rank | Genre | Avg Duration (min) | Track Count |
// |------|--------------------|--------------------|-------------|
// | 1 | Sci Fi & Fantasy | 48.53 | 26 |
// | 2 | Science Fiction | 43.76 | 13 |
// | 3 | Drama | 42.92 | 64 |
// | 4 | TV Shows | 35.75 | 93 |
// | 5 | Comedy | 26.42 | 17 |
//
// Notably, the top genres are all **TV/film-related content**, which makes sense — those "tracks" are likely full TV episodes rather than music, naturally resulting in much longer durations.

// %% [markdown]
// Let's ask for a simple list of all tables in the database.

// %%
const question = "What are all the tables?";
const stream = await agent.stream({
    messages: question
}, {
    streamMode: "values",
    context: {
        db,
    }
})

for await (const step of stream) {
    const lastMessage = step?.messages?.at(-1)
    displayMessage(lastMessage)
}
// Out:
// ┌────────────────────────────────────────────────────────────┐
// │ 👤 HUMAN MESSAGE                                           │
// └────────────────────────────────────────────────────────────┘
// What are all the tables?
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "tool_use",
//     id: "toolu_01UgRE2YsdsTMoKKL92uiAg1",
//     name: "execute_sql",
//     input: {
//       query: "SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;"
//     },
//     caller: { type: "direct" }
//   }
// ]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"name":"Album"},{"name":"Artist"},{"name":"Customer"},{"name":"Employee"},{"name":"Genre"},{"name":"Invoice"},{"name":"InvoiceLine"},{"name":"MediaType"},{"name":"Playlist"},{"name":"PlaylistTrack"},{"name":"Track"}]
//
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// There are **11 tables** in the database:
//
// | # | Table Name |
// |---|------------|
// | 1 | Album |
// | 2 | Artist |
// | 3 | Customer |
// | 4 | Employee |
// | 5 | Genre |
// | 6 | Invoice |
// | 7 | InvoiceLine |
// | 8 | MediaType |
// | 9 | Playlist |
// | 10 | PlaylistTrack |
// | 11 | Track |
//
// This looks like a **music store database** (commonly known as the Chinook database), containing information about artists, albums, tracks, playlists, customers, employees, and sales (invoices). Would you like to explore any of these tables further?

// %% [markdown]
// ## Let's try this in the agent debugger!
//
// The "Getting Setup" instructions describe how to get LangSmith Studio set up. If you are running the notebooks, you are probably already to go.
// The messages are in a slightly different format than in the course video:
// ```typescript
// {
//   "messages":  "Which table has the largest number of entries?"
// }
// ```
// With brackets in json format.
//
// Watch this video to see how to invoke it.
//
//
// <video src="assets/RunningStudio_H264.mp4" width="720" controls poster="assets/thumb.jpg" playsinline></video>
